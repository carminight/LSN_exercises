# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory </span>
# ## <span style="color:brown"> Python Exercise 11 </span>
# ## <span style="color:orange"> Keras - Neural Network regression </span>

# %% [markdown]
# ### Overview
#
# In this notebook our task will be to perform machine learning regression on noisy data with a Neural Network (NN).
#
# We will explore how the ability to fit depends on the structure of the NN. The goal is also to build intuition about why prediction is difficult.

# %% [markdown]
# ### The Prediction Problem
#
# Consider a probabilistic process that gives rise to labeled data $(x,y)$. The data is generated by drawing samples from the equation
#
# $$
#     y_i= f(x_i) + \eta_i,
# $$
#
# where $f(x_i)$ is some fixed, but (possibly unknown) function, and $\eta_i$ is a Gaussian, uncorrelate noise variable such that
#
# $$
# \langle \eta_i \rangle=0 \\
# \langle \eta_i \eta_j \rangle = \delta_{ij} \sigma
# $$
#
# We will refer to the $f(x_i)$ as the **true features** used to generate the data.
#
# To make prediction, we will consider a NN that depend on its parameters, weights and biases. The functions that the NN can model respresent the **model class** that we are using to try to model the data and make predictions.
#
# To learn the parameters of the NN, we will train our models on a **training data set** and then test the effectiveness of the NN on a *different* dataset, the **validation data set**. The reason we must divide our data into a training and test dataset is that the point of machine learning is to make accurate predictions about new data we have not seen.
#
# To measure our ability to predict, we will learn our parameters by fitting our training dataset and then making predictions on our test data set. One common measure of predictive  performance of our algorithm is to compare the predictions,$\{y_j^\mathrm{pred}\}$, to the true values $\{y_j\}$. A commonly employed measure for this is the sum of the mean square-error (MSE) on the test set:
# $$
# MSE= \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2
# $$
#
# We will try to get a qualitative picture by examining plots on validation and training data.

# %% [markdown]
# ### Linear fit
#
# We start by considering the very simple case:
# $$
# f(x)=2x+1
# $$

# %% [markdown]
# Let's start defining the parameters of an ideal linear function which we are going to predict through a neural network regression

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %% [markdown]
# Now let's generate a set of input data which will slightly deviate from our ideal behaviour using a random noise (that actually is set to zero):

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 1000)
x_valid = np.random.uniform(-1, 1, 100)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0.5 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %% [markdown]
# If you remember how a single node of a neural network works, you can easily spot that **just a single neuron can make the job**. So let's start using a simple Sequential model with just one layer on one neuron only!

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We are now going to train our model, that is we feed the neuron with the set of training pair x, y_train from which the optimizer will find the best weights to minimize the Mean Square Error loss function (out linear regression function).

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Train on 1000 samples, validate on 100 samples
# WARNING:tensorflow:From /Users/riccardoaiolfi/Downloads/intelpython3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 1000/1000 [==============================] - 0s 144us/sample - loss: 1.3668 - mean_squared_error: 1.3668 - val_loss: 1.0454 - val_mean_squared_error: 1.0454
# Epoch 2/100
# 1000/1000 [==============================] - 0s 27us/sample - loss: 0.7567 - mean_squared_error: 0.7567 - val_loss: 0.6732 - val_mean_squared_error: 0.6732
# Epoch 3/100
# 1000/1000 [==============================] - 0s 27us/sample - loss: 0.5175 - mean_squared_error: 0.5175 - val_loss: 0.5005 - val_mean_squared_error: 0.5005
# Epoch 4/100
# 1000/1000 [==============================] - 0s 25us/sample - loss: 0.4056 - mean_squared_error: 0.4056 - val_loss: 0.4002 - val_mean_squared_error: 0.4002
# Epoch 5/100
# 1000/1000 [==============================] - 0s 25us/sample - loss: 0.3421 - mean_squared_error: 0.3421 - val_loss: 0.3389 - val_mean_squared_error: 0.3389
# Epoch 6/100
# 1000/1000 [==============================] - 0s 25us/sample - loss: 0.3047 - mean_squared_error: 0.3047 - val_loss: 0.2954 - val_mean_squared_error: 0.2954
# Epoch 7/100
# 1000/1000 [==============================] - 0s 25us/sample - loss: 0.2793 - mean_squared_error: 0.2793 - val_loss: 0.2688 - val_mean_squared_error: 0.2688
# Epoch 8/100
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.2645 - mean_squared_error: 0.2645 - val_loss: 0.2505 - val_mean_squared_error: 0.2505
# Epoch 9/100
# 1000/1000 [==============================] - 0s 25us/sample - loss: 0.2549 - mean_squared_error: 0.2549 - val_loss: 0.2383 - val_mean_squared_error: 0.2383
# Epoch 10/100
# 1000/1000 [==============================] - 0s 25us/sample - loss: 0.2489 - mean_squared_error: 0.2489 - val_loss: 0.2294 - val_mean_squared_error: 0.2294
# Epoch 11/100
# 1000/1000 [==============================] - 0s 26us/sample - loss: 0.2448 - mean_squared_error: 0.2448 - val_loss: 0.2226 - val_mean_squared_error: 0.2226
# Epoch 12/100
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.2419 - mean_squared_error: 0.2419 - val_loss: 0.2181 - val_mean_squared_error: 0.2181
# Epoch 13/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2402 - mean_squared_error: 0.2402 - val_loss: 0.2148 - val_mean_squared_error: 0.2148
# Epoch 14/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2391 - mean_squared_error: 0.2391 - val_loss: 0.2124 - val_mean_squared_error: 0.2124
# Epoch 15/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2384 - mean_squared_error: 0.2384 - val_loss: 0.2102 - val_mean_squared_error: 0.2102
# Epoch 16/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2378 - mean_squared_error: 0.2378 - val_loss: 0.2090 - val_mean_squared_error: 0.2090
# Epoch 17/100
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.2375 - mean_squared_error: 0.2375 - val_loss: 0.2081 - val_mean_squared_error: 0.2081
# Epoch 18/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2373 - mean_squared_error: 0.2373 - val_loss: 0.2074 - val_mean_squared_error: 0.2074
# Epoch 19/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2372 - mean_squared_error: 0.2372 - val_loss: 0.2070 - val_mean_squared_error: 0.2070
# Epoch 20/100
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.2372 - mean_squared_error: 0.2372 - val_loss: 0.2066 - val_mean_squared_error: 0.2066
# Epoch 21/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2063 - val_mean_squared_error: 0.2063
# Epoch 22/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2372 - mean_squared_error: 0.2372 - val_loss: 0.2059 - val_mean_squared_error: 0.2059
# Epoch 23/100
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2059 - val_mean_squared_error: 0.2059
# Epoch 24/100
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 25/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 26/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2055 - val_mean_squared_error: 0.2055
# Epoch 27/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 28/100
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.2372 - mean_squared_error: 0.2372 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 29/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 30/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2055 - val_mean_squared_error: 0.2055
# Epoch 31/100
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2055 - val_mean_squared_error: 0.2055
# Epoch 32/100
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 33/100
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 34/100
# 1000/1000 [==============================] - 0s 25us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 35/100
# 1000/1000 [==============================] - 0s 27us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2055 - val_mean_squared_error: 0.2055
# Epoch 36/100
# 1000/1000 [==============================] - 0s 25us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 37/100
# 1000/1000 [==============================] - 0s 30us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 38/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2050 - val_mean_squared_error: 0.2050
# Epoch 39/100
# 1000/1000 [==============================] - 0s 27us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 40/100
# 1000/1000 [==============================] - 0s 26us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 41/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 42/100
# 1000/1000 [==============================] - 0s 28us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 43/100
# 1000/1000 [==============================] - 0s 27us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 44/100
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 45/100
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 46/100
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 47/100
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 48/100
# 1000/1000 [==============================] - 0s 23us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 49/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 50/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 51/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 52/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 53/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 54/100
# 1000/1000 [==============================] - 0s 26us/sample - loss: 0.2372 - mean_squared_error: 0.2372 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 55/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2050 - val_mean_squared_error: 0.2050
# Epoch 56/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2372 - mean_squared_error: 0.2372 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 57/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 58/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2370 - mean_squared_error: 0.2370 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 59/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 60/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 61/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 62/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 63/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 64/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 65/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 66/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 67/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 68/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 69/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 70/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 71/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 72/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 73/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 74/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 75/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 76/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2056 - val_mean_squared_error: 0.2056
# Epoch 77/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2372 - mean_squared_error: 0.2372 - val_loss: 0.2055 - val_mean_squared_error: 0.2055
# Epoch 78/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2057 - val_mean_squared_error: 0.2057
# Epoch 79/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2055 - val_mean_squared_error: 0.2055
# Epoch 80/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 81/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 82/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2050 - val_mean_squared_error: 0.2050
# Epoch 83/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2372 - mean_squared_error: 0.2372 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 84/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2370 - mean_squared_error: 0.2370 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 85/100
# 1000/1000 [==============================] - 0s 22us/sample - loss: 0.2370 - mean_squared_error: 0.2370 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 86/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 87/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2051 - val_mean_squared_error: 0.2051
# Epoch 88/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 89/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2054 - val_mean_squared_error: 0.2054
# Epoch 90/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 91/100
# 1000/1000 [==============================] - 0s 20us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 92/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2052 - val_mean_squared_error: 0.2052
# Epoch 93/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2370 - mean_squared_error: 0.2370 - val_loss: 0.2048 - val_mean_squared_error: 0.2048
# Epoch 94/100
# 1000/1000 [==============================] - 0s 21us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2046 - val_mean_squared_error: 0.2046
# Epoch 95/100
# 1000/1000 [==============================] - 0s 25us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2047 - val_mean_squared_error: 0.2047
# Epoch 96/100
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2048 - val_mean_squared_error: 0.2048
# Epoch 97/100
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2047 - val_mean_squared_error: 0.2047
# Epoch 98/100
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2047 - val_mean_squared_error: 0.2047
# Epoch 99/100
# 1000/1000 [==============================] - 0s 24us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2049 - val_mean_squared_error: 0.2049
# Epoch 100/100
# 1000/1000 [==============================] - 0s 25us/sample - loss: 0.2371 - mean_squared_error: 0.2371 - val_loss: 0.2048 - val_mean_squared_error: 0.2048

# %%
# return weights
model.get_weights()
# Out:
# [array([[2.010798]], dtype=float32), array([1.0033811], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 100/100 [==============================] - 0s 36us/sample - loss: 0.2048 - mean_squared_error: 0.2048
#
# Test loss: 0.20476943552494048
# Test accuracy: 0.20476943

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 100/100 [==============================] - 0s 34us/sample - loss: 5.3809e-05 - mean_squared_error: 5.3809e-05
#
# Test loss: 5.380923161283136e-05
# Test accuracy: 5.3809235e-05

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 11.1
#
# In order to make practice with NN, explore how does the previous linear regression depend on the number of epochs, $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$. Try to improve the previous result operating on these parameters.

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# In order to make practice with NN, explore reasonable different choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Make graphs comparing fits for different NNs.
# Check your NN models by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %% [markdown]
# Ideas to meditate on these exercises and judge your results can be found <a href=https://xkcd.com/2048/>here</a>

# %% [markdown]
# ### <span style="color:green">Supplementary material: Keras model.fit available callbacks</span>

# %% [markdown]
# The .fit method can also get <a href=https://keras.io/callbacks/>callback</a> functions which can be used to customize the fitting procedure with special actions.
#
# Keras provides some predefined callbacks to feed in, among them for example:
# - **TerminateOnNaN()**: that terminates training when a NaN loss is encountered
# - **ModelCheckpoint(filepath)**: that save the model after every epoch
# - **EarlyStopping()**: which stop training when a monitored quantity has stopped improving
#
# You can select one or more callback and pass them as a list to the callback argument of the fit method.

# %% [markdown]
# Now we are going to construct a callback object to represent how estimated parameters are converging during the training procedure

# %%
from IPython.display import clear_output

class PlotCurrentEstimate(tf.keras.callbacks.Callback):
    def __init__(self, x_valid, y_valid):
        """Keras Callback which plot current model estimate against reference target"""
        
        # convert numpy arrays into lists for plotting purposes
        self.x_valid = list(x_valid[:])
        self.y_valid = list(y_valid[:])
        self.iter=0

    def on_epoch_end(self, epoch, logs={}):
        
        temp = self.model.predict(self.x_valid, batch_size=None, verbose=False, steps=None)
        self.y_curr = list(temp[:]) # convert numpy array into list
        
        self.iter+=1
        if self.iter%10 == 0:
            clear_output(wait=True)            
            self.eplot = plt.subplot(1,1,1)
            self.eplot.clear()     
            self.eplot.scatter(self.x_valid, self.y_curr, color="blue", s=4, marker="o", label="estimate")
            self.eplot.scatter(self.x_valid, self.y_valid, color="red", s=4, marker="x", label="valid")
            self.eplot.legend()

            plt.show()

# %% [markdown]
# We will use also an EarlyStopping callback on the val_loss quantity. This will stop the training process as soon as the val_loss quantity does not improve anymore after an amount of epochs, preventing a long time of wated computation to take over without useful results.
#
# <code>keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=False)</code>
#
# Arguments:
#
# - <code>monitor</code>: quantity to be monitored.
# - <code>min_delta:</code> minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
# - <code>patience:</code> number of epochs with no improvement after which training will be stopped.
# - <code>verbose:</code> verbosity mode.
# - <code>mode:</code> one of {auto, min, max}. In min mode, training will stop when the quantity monitored has stopped decreasing; in max mode it will stop when the quantity monitored has stopped increasing; in auto mode, the direction is automatically inferred from the name of the monitored quantity.
# - <code>baseline:</code> Baseline value for the monitored quantity to reach. Training will stop if the model doesn't show improvement over the baseline.
# - <code>restore_best_weights:</code> whether to restore model weights from the epoch with the best value of the monitored quantity. If False, the model weights obtained at the last step of training are used.

# %%
plot_estimate = PlotCurrentEstimate(x_valid, y_valid)

earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                  min_delta=0, patience=100, mode='auto')

model.fit(x_valid, y_valid, batch_size=32, epochs=150,
          validation_data=(x_valid, y_valid),
          callbacks=[ plot_estimate, earlystop]
          )

model.get_weights()
# Out:
# 10/10 [==============================] - 0s 12ms/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# [array([[1.9060694]], dtype=float32), array([1.0136849], dtype=float32)]
