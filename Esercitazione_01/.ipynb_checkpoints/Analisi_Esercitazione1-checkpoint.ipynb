# %% [markdown]
# ESERCIZIO 1

# %%
file = open("results1.txt")
cont = file.read()
print(cont)
file.close
# Out:
# 0  0.506394  0
# 1000  0.505419  0.000975434
# 2000  0.506531  0.00124642
# 3000  0.50366  0.00300341
# 4000  0.502191  0.00275126
# 5000  0.500854  0.0026139
# 6000  0.503536  0.00347441
# 7000  0.504052  0.00305291
# 8000  0.503583  0.00273295
# 9000  0.501214  0.00340415
# 10000  0.499985  0.00331548
# 11000  0.50016  0.00303163
# 12000  0.500513  0.00281098
# 13000  0.500319  0.00260967
# 14000  0.500069  0.00244235
# 15000  0.502089  0.00305001
# 16000  0.501955  0.00286812
# 17000  0.50203  0.00270512
# 18000  0.50241  0.00258682
# 19000  0.502239  0.00245996
# 20000  0.502193  0.00234034
# 21000  0.502628  0.00227343
# 22000  0.501909  0.00228835
# 23000  0.501397  0.00224989
# 24000  0.501469  0.00215921
# 25000  0.500565  0.00226315
# 26000  0.500407  0.00218344
# 27000  0.500215  0.0021127
# 28000  0.500182  0.00203881
# 29000  0.500143  0.00197007
# 30000  0.499822  0.00193239
# 31000  0.499685  0.00187603
# 32000  0.499734  0.00181896
# 33000  0.499716  0.00176474
# ...
